# %% [markdown]
# <a href="https://colab.research.google.com/github/k242565-art/flyrank-ml-internship/blob/main/capstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Capstone — mirrors your deployed research paper
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/k242565-art/flyrank-ml-internship/blob/main/work/notebooks/capstone.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Question
#
# *The research question and the decision it supports.*

# %% [markdown]
# ## 2. Data
#
# *Which release, which tables, date windows, what you excluded and why. Public-safe.*

# %% [markdown]
# ## 3. Methodology
#
# *Assumptions, features, label definition, baseline, validation design, leakage checks.*

# %% [markdown]
# ## 4. Results (vs baseline)
#
# *Model vs baseline on the same split. The honest table.*

# %% [markdown]
# ## 5. Limitations
#
# *What this work cannot claim.*

# %% [markdown]
# ## 6. Ranked recommendations
#
# *The action playbook output — the paper's recommendations section.*

# %% [markdown]
# ## 7. Artifacts the paper embeds
#
# *Generate/collect the charts and tables your deployed page will show.*

# %% [markdown]
# # Week 8 Showcase Demo Outline (5 Minutes)
#
# ## 1. Problem (1 Minute)
#
# FlyRank manages large content portfolios where manual review of every page is not practical. The goal was to identify content that may benefit from refresh actions using historical search-performance data.
#
# ## 2. Method (1 Minute)
#
# - Built a rule-based baseline using content age and trend signals.
# - Audited signals for validity.
# - Trained a Random Forest model.
# - Compared model performance against the baseline.
# - Validated results using grouped evaluation and leakage checks.
#
# ## 3. Key Chart (1 Minute)
#
# Show the Model vs Baseline comparison chart.
#
# ## 4. Honest Result (1 Minute)
#
# The machine-learning model outperformed the baseline on the same evaluation framework. However, the results are observational and should be interpreted as decision-support rather than prediction of future outcomes.
#
# ## 5. Recommendation (1 Minute)
#
# Use the model-generated queue to prioritize editorial review of aging and declining content. Final decisions should remain under human review.
# # Shareable Social Post
#
# I recently completed a machine learning capstone using the FlyRank ML Internship dataset.
#
# The project focused on content refresh prioritization, combining signal audits, rule-based baselines, machine learning, validation audits, and action-playbook design. Rather than optimizing for complexity, the emphasis was on honest evaluation, leakage prevention, and decision-support recommendations.
#
# Project paper:
# https://k242565-art.github.io/flyrank-ml-internship/
#
# # Employer-Facing Summary
#
# I built a content-refresh prioritization system using the FlyRank ML Internship dataset and historical search-performance signals.
#
# The project included baseline development, machine-learning modeling, grouped validation, leakage auditing, and recommendation design using real production-scale search data.
#
# The final result was a decision-support framework that helps prioritize content review opportunities while maintaining transparent validation and public-safe reporting practices.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
# - [ ] My deployed paper has **all 9 sections** — including the **Abstract** at the top and **Acknowledgments & data credit** (the https://flyrank.ai link) at the bottom.
# - [ ] **ML-12 done in this notebook's closing cells:** 5-minute demo outline + a social-post cut + a 3-sentence employer-facing summary.

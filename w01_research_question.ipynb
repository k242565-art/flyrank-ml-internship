# %% [markdown]
# <a href="https://colab.research.google.com/github/k242565-art/flyrank-ml-internship/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/k242565-art/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
# Lane: Refresh / Content Opportunity Scoring
# I'm picking this lane because notebook 01/02 showed a learned model beating a hand-written rule by 3x on precision@50 (0.240 → 0.740) — that gap tells me there's real signal in the observable features (impressions, position, freshness, CTR) that a simple rule misses. With review capacity always limited, a ranked queue that's demonstrably more accurate than a flat rule has an immediate, obvious use.# This cell is for CODE (numbers, a query, a check).
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
# Unit of analysis	:One content page (content_id), scored using its trailing 90-day window
# Decision	:Which pages the content team should review first this sprint
# Action	:Reviewer opens the top-N pages from the ranked queue and decides: refresh, expand, protect, prune, or monitor
# Cost of a wrong call	:False positive: writer hours spent refreshing a page that wasn't actually declining. False negative: a genuinely declining high-traffic page gets missed and keeps losing visibility
# Why data/ML helps	With 30k+ pages (and potentially 500k+ in the warehouse), no one can manually eyeball every page's 90-day trend across impressions, position, and CTR simultaneously — the model can rank by combined evidence at a scale a human reviewer can't replicate by hand

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os
print(os.getcwd())
print(os.listdir('.'))
import os

if not os.path.exists('flyrank-ml-internship'):
    # !git clone https://github.com/k242565-art/flyrank-ml-internship.git

os.chdir('flyrank-ml-internship')
print(os.getcwd())
print(os.listdir('.'))
import pandas as pd
df = pd.read_csv('data/raw/content_refresh_anonymized.csv')
print(df.shape)
# Out:
# /content/flyrank-ml-internship/flyrank-ml-internship/flyrank-ml-internship/flyrank-ml-internship
# ['skills', '.github', 'submission', '.gitignore', 'GUIDE.md', 'DATA_USE.md', '02_your_first_readable_model.ipynb', 'Copy_of_01_first_look_and_discovery.ipynb', 'SETUP.md', '.git', 'work', 'outputs', 'requirements.txt', 'data', 'README.md', 'LICENSE', 'CLAUDE.md', 'scripts', 'AGENTS.md', 'notebooks', 'docs']
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 117, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 117 (delta 32), reused 96 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (117/117), 1.84 MiB | 14.08 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# /content/flyrank-ml-internship/flyrank-ml-internship/flyrank-ml-internship/flyrank-ml-internship/flyrank-ml-internship
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
# This is decision-support, not causal proof — a ranked review list, not a guarantee that fixing a page will recover its traffic. I observed a correlation/pattern in the anonymized starter sample; I'm not claiming this reflects Google's ranking algorithm, and I have not run any experiment that would let me claim a refresh causes recovery. All numbers here come from the small starter dataset (30k rows), not the full warehouse, so conclusions are provisional until validated on more data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
